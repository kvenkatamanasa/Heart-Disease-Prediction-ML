# %%
import pandas as pd

# %%
data=pd.read_csv('heart.csv')
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
X=data.drop("target",axis=1)
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
Y=data["target"]
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)
X_train
X_test
Y_train
Y_test
# Out:
# 527    1
# 359    1
# 447    0
# 31     1
# 621    0
#       ..
# 832    1
# 796    1
# 644    1
# 404    0
# 842    0
# Name: target, Length: 205, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
gb=GradientBoostingClassifier()
gb.fit(X_train,Y_train)
# Out:
# GradientBoostingClassifier()

# %%
Y_pred2=knn.predict(X_test)
Y_pred3=dt.predict(X_test)
Y_pred4=rf.predict(X_test)
Y_pred5=gb.predict(X_test)

# %%
from sklearn import metrics

# %%
score1=metrics.r2_score(Y_test,Y_pred2)
score2=metrics.r2_score(Y_test,Y_pred3)
score3=metrics.r2_score(Y_test,Y_pred4)

# %%
score1,score2,score3
# Out:
# (-0.07319626879878194, 0.9414620217018846, 0.9414620217018846)

# %%
gb=GradientBoostingClassifier()
gb_final=gb.fit(X,Y)

# %%
import joblib

# %%
model=joblib.dump(gb_final,'models/carpriceprediction')

# %%
model=joblib.load('models/carpriceprediction')

# %%
import pandas as pd

# %%
data_new=pd.DataFrame({
    'age':55,
    'sex':1,
    'cp':0,
    'trestbps':140,
    'chol':250,
    'fbs':0,
    'restecg':0,
    'thalach':150,
    'exang':0,
    'oldpeak':1.0,
    'slope':1,
    'ca':0,
    'thal':2,
},index=[0])

# %%
model.predict(data_new)
# Out:
# array([1])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data["age"], data["target"], alpha=0.5, color="blue")
plt.xlabel("Age")
plt.ylabel("Target")
plt.title(" ")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x="age", hue="target", palette="Set2")
plt.title("Heart Disease Count by Age")
plt.xlabel("Age")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
sns.swarmplot(data=data, x="target", y="age", palette="Set1")
plt.title("Age Distribution per Target Class")
plt.xlabel("Target (0 = No Disease, 1 = Disease)")
plt.ylabel("Age")
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_17720\1673369756.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=data, x="target", y="age", palette="Set1")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x="age", y="chol", hue="target", palette="coolwarm", s=60)
plt.xlabel("Age")
plt.ylabel("Cholesterol")
plt.title("Age vs Cholesterol ")
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
counts = data["target"].value_counts()
categories = ["No Disease (0)", "Disease (1)"]

# %%
plt.figure(figsize=(6, 4))
plt.stem(categories, counts, linefmt="C0-", markerfmt="C0o", basefmt=" ")
plt.ylabel("Number of Patients")
plt.title("Heart Disease Classification")
plt.ylim(0, max(counts) + 100)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
data["target"].value_counts().plot(
    kind="pie", 
    autopct="%1.1f%%", 
    labels=["Disease", "No Disease"], 
    colors=["#3498db", "#e74c3c"], 
    explode=(0.05, 0), 
    startangle=140
)
plt.title("Heart Disease Distribution")
plt.ylabel("")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data["age"], bins=10, kde=True, color="skyblue", edgecolor="black")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age Distribution")
plt.show()
prediction = model.predict(data_new)
if prediction[0] == 1:
    print("The person has Heart Disease")
else:
    print("The person does NOT have Heart Disease")
# Out:
# The person has Heart Disease
